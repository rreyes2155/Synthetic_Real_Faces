# %% [markdown]
# <a href="https://colab.research.google.com/github/rreyes2155/Synthetic_Real_Faces/blob/main/Load_Data_to_Bucket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'data-606-capstone'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://data690deeplearning/
# gs://mura_data_606/

# %%
bucket_name = 'data690deeplearning'
# !gsutil -m cp -r /content/drive/My\ Drive/faces_data/celebahq/* gs://{bucket_name}/
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img014805.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img003577.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img019038.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img011939.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img008492.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img024644.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/celebahq/celebahq/data1024x1024/img022873.jpg [Content-Type=image/jpeg]...
# ...

# %%
bucket_name = 'data690deeplearning'
# !gsutil -m cp -r /content/drive/My\ Drive/faces_data/lama/* gs://{bucket_name}/
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img010320.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img007786.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img008799.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img008305.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img010387.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/lama/lama/lama-dataset/celeb/lamaFourier/img007243.jpg [Content-Type=image/jpeg]...
# ...

# %%
bucket_name = 'data690deeplearning'
# !gsutil -m cp -r /content/drive/My\ Drive/faces_data/mat/* gs://{bucket_name}/
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img023474.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img027722.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img022712.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img019212.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img009319.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img003470.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img006706.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/faces_data/mat/mat/celebahq/img009276.jpg [Content-Type=image/jpeg]...
# ...
